# %%
from bs4 import BeautifulSoup # import BeautifulSoup and requests
import requests
from requests import get

# %%
html_page = requests.get('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&') # Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') # Pass the page contents to beautiful soup for parsing 0-200

# %%
html_page_200 = requests.get('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=200') # Make a get request to retrieve the page
soup_200 = BeautifulSoup(html_page_200.content, 'html.parser') # Pass the page contents to beautiful soup for parsing 200-400

# %%
html_page_400 = requests.get('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=400') # Make a get request to retrieve the page
soup_400 = BeautifulSoup(html_page_400.content, 'html.parser') # Pass the page contents to beautiful soup for parsing 400-600

# %%
html_page_600 = requests.get('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=600') # Make a get request to retrieve the page
soup_600 = BeautifulSoup(html_page_600.content, 'html.parser') # Pass the page contents to beautiful soup for parsing 600-800

# %%
html_page_800 = requests.get('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=800') # Make a get request to retrieve the page
soup_800 = BeautifulSoup(html_page_800.content, 'html.parser') # Pass the page contents to beautiful soup for parsing 800-1000

# %%
html_page_1000 = requests.get('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=1000') # Make a get request to retrieve the page
soup_1000 = BeautifulSoup(html_page_1000.content, 'html.parser') # Pass the page contents to beautiful soup for parsing 1000-1200

# %%
html_page_1200 = requests.get('https://www.boxofficemojo.com/chart/ww_top_lifetime_gross/?area=XWW&offset=1200') # Make a get request to retrieve the page
soup_1200 = BeautifulSoup(html_page_1200.content, 'html.parser') # Pass the page contents to beautiful soup for parsing 1200-1400

#Looping took too long to figure out how to make work, so I created extra variables

# %%
soup.prettify #Checking if read
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# ...

# %%
soup_200.prettify #Checking if second soup read
# Out:
# <bound method Tag.prettify of <!DOCTYPE doctype html>
# <html class="a-no-js" data-19ax5a9jf="dingo"><head><script>var aPageStart = (new Date()).getTime();</script><meta charset="utf-8"/><meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <meta charset="utf-8"/>
# <title dir="ltr">Top Lifetime Grosses - Box Office Mojo</title><meta content="Top Lifetime Grosses" name="title"/>
# <meta content="Box Office Mojo" property="og:site_name"/>
# <meta content="telephone=no" name="format-detection"/>
# <link href="https://m.media-amazon.com/images/G/01/boxofficemojo/v2/favicon._CB448965889_.ico" rel="icon" type="image/x-icon"/>
# ...

# %%
#creating movie container
movie_container = soup.find('div', class_="a-section imdb-scroll-table-inner")
movie_container
# Out:
# <div class="a-section imdb-scroll-table-inner"><table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# ...

# %%
#Creating movie containers for all pages
movie_container_200 = soup_200.find('div', class_="a-section imdb-scroll-table-inner")
movie_container_200
# Out:
# <div class="a-section imdb-scroll-table-inner"><table class="a-bordered a-horizontal-stripes a-size-base a-span12 mojo-body-table mojo-table-annotated"><tr><th class="a-text-right mojo-field-type-rank a-nowrap"><span title="Rank">Rank</span>
# </th><th class="a-text-left mojo-field-type-title a-nowrap"><span title="Title">Title</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Worldwide Lifetime Gross">Worldwide Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Domestic Lifetime Gross">Domestic Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Domestic %">Domestic %</span>
# </th><th class="a-text-right mojo-field-type-money a-nowrap"><span title="Foreign Lifetime Gross">Foreign Lifetime Gross</span>
# </th><th class="a-text-right mojo-field-type-percent a-nowrap"><span title="Foreign %">Foreign %</span>
# ...

# %%
movie_container_400 = soup_400.find('div', class_="a-section imdb-scroll-table-inner")

# %%
movie_container_600 = soup_600.find('div', class_="a-section imdb-scroll-table-inner")

# %%
movie_container_800 = soup_800.find('div', class_="a-section imdb-scroll-table-inner")

# %%
movie_container_1000 = soup_1000.find('div', class_="a-section imdb-scroll-table-inner")

# %%
movie_container_1200 = soup_1200.find('div', class_="a-section imdb-scroll-table-inner")

# %%
#finding all strings that are relvant to data
movie_container = soup.find_all('tr')
movie_container_200 = soup_200.find_all('tr')
movie_container_400 = soup_400.find_all('tr')
movie_container_600 = soup_600.find_all('tr')
movie_container_800 = soup_800.find_all('tr')
movie_container_1000 = soup_1000.find_all('tr')
movie_container_1200 = soup_1200.find_all('tr')

#checking to see if there are 200 films per page
print(type(movie_container))
print(len(movie_container))
print(len(movie_container_200))
print(len(movie_container_400))
print(len(movie_container_600))
print(len(movie_container_800))
print(len(movie_container_1000))
print(len(movie_container_1200))
# Out:
# <class 'bs4.element.ResultSet'>
# 201
# 201
# 201
# 201
# 201
# 201
# 201

# %%
#Checking highest ranked film per page
print(movie_container[1].findAll('td')[0].string)
print(movie_container_200[1].findAll('td')[0].string)
print(movie_container_400[1].findAll('td')[0].string)
print(movie_container_600[1].findAll('td')[0].string)
print(movie_container_800[1].findAll('td')[0].string)
print(movie_container_1000[1].findAll('td')[0].string)
print(movie_container_1200[1].findAll('td')[0].string)
# Out:
# 1
# 201
# 402
# 605
# 808
# 1,015
# 1,219

# %%
#Checking to see if top row is headers
movie_container[0].findAll('span')[0].string
movie_container_200[0].findAll('span')[0].string
# Out:
# 'Rank'

# %%
headers=movie_container[0]
headers.findAll('span')[0].string
# Out:
# 'Rank'

# %%
# making headers for dataframe
headers_string=[]
index_list = list(range(0,8)) # 9 categories 

for index in index_list:
    headers_string.append(headers.findAll('span')[index].string)

# %%
headers_string
# Out:
# ['Rank',
#  'Title',
#  'Worldwide Lifetime Gross',
#  'Domestic Lifetime Gross',
#  'Domestic %',
#  'Foreign Lifetime Gross',
#  'Foreign %',
#  'Year']

# %%
# Checking to see if read
movie_container[1]
# Out:
# <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154796/?ref_=bo_cso_table_1">Avengers: Endgame</a></td><td class="a-text-right mojo-field-type-money">$2,797,800,564</td><td class="a-text-right mojo-field-type-money">$858,373,000</td><td class="a-text-right mojo-field-type-percent">30.7%</td><td class="a-text-right mojo-field-type-money">$1,939,427,564</td><td class="a-text-right mojo-field-type-percent">69.3%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2019/?ref_=bo_cso_table_1">2019</a></td></tr>

# %%
movie_container_200[1]
# Out:
# <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">201</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt5013056/?ref_=bo_cso_table_1">Dunkirk</a></td><td class="a-text-right mojo-field-type-money">$526,940,665</td><td class="a-text-right mojo-field-type-money">$189,740,665</td><td class="a-text-right mojo-field-type-percent">36%</td><td class="a-text-right mojo-field-type-money">$337,200,000</td><td class="a-text-right mojo-field-type-percent">64%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2017/?ref_=bo_cso_table_1">2017</a></td></tr>

# %%
movie_container_400[2]
# Out:
# <tr><td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">403</td><td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt1679335/?ref_=bo_cso_table_2">Trolls</a></td><td class="a-text-right mojo-field-type-money">$346,864,462</td><td class="a-text-right mojo-field-type-money">$153,707,064</td><td class="a-text-right mojo-field-type-percent">44.3%</td><td class="a-text-right mojo-field-type-money">$193,157,398</td><td class="a-text-right mojo-field-type-percent">55.7%</td><td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2016/?ref_=bo_cso_table_2">2016</a></td></tr>

# %%
movie_container[1].findAll('td')[0].string
# Out:
# '1'

# %%
movie_container_200[1].findAll('td')[0].string
# Out:
# '201'

# %%
# Making for loop to create a list of attributes for each movie
movies=[]
index_range = list(range(1,len(movie_container)))
'''Finds all td in all values of movie_container and appends to movies list.
    Repeated for movies in all ranges'''
for index in index_range:
    movies.append(movie_container[index].findAll('td'))
movies[0]
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt4154796/?ref_=bo_cso_table_1">Avengers: Endgame</a></td>,
#  <td class="a-text-right mojo-field-type-money">$2,797,800,564</td>,
#  <td class="a-text-right mojo-field-type-money">$858,373,000</td>,
#  <td class="a-text-right mojo-field-type-percent">30.7%</td>,
#  <td class="a-text-right mojo-field-type-money">$1,939,427,564</td>,
#  <td class="a-text-right mojo-field-type-percent">69.3%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2019/?ref_=bo_cso_table_1">2019</a></td>]

# %%
movie_container_200[1].findAll('td')
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">201</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt5013056/?ref_=bo_cso_table_1">Dunkirk</a></td>,
#  <td class="a-text-right mojo-field-type-money">$526,940,665</td>,
#  <td class="a-text-right mojo-field-type-money">$189,740,665</td>,
#  <td class="a-text-right mojo-field-type-percent">36%</td>,
#  <td class="a-text-right mojo-field-type-money">$337,200,000</td>,
#  <td class="a-text-right mojo-field-type-percent">64%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2017/?ref_=bo_cso_table_1">2017</a></td>]

# %%
movies_200=[]
index_range_200 = list(range(1,len(movie_container_200)))
for index_200 in index_range_200:
    movies_200.append(movie_container_200[index_200].findAll('td'))
movies_200[0]
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">201</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt5013056/?ref_=bo_cso_table_1">Dunkirk</a></td>,
#  <td class="a-text-right mojo-field-type-money">$526,940,665</td>,
#  <td class="a-text-right mojo-field-type-money">$189,740,665</td>,
#  <td class="a-text-right mojo-field-type-percent">36%</td>,
#  <td class="a-text-right mojo-field-type-money">$337,200,000</td>,
#  <td class="a-text-right mojo-field-type-percent">64%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2017/?ref_=bo_cso_table_1">2017</a></td>]

# %%
movies_400=[]
index_range_400 = list(range(1,len(movie_container_400)))
for index_400 in index_range_400:
    movies_400.append(movie_container_400[index_400].findAll('td'))
movies_400[0]
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">402</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0266915/?ref_=bo_cso_table_1">Rush Hour 2</a></td>,
#  <td class="a-text-right mojo-field-type-money">$347,325,802</td>,
#  <td class="a-text-right mojo-field-type-money">$226,164,286</td>,
#  <td class="a-text-right mojo-field-type-percent">65.1%</td>,
#  <td class="a-text-right mojo-field-type-money">$121,161,516</td>,
#  <td class="a-text-right mojo-field-type-percent">34.9%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2001/?ref_=bo_cso_table_1">2001</a></td>]

# %%
movies_600=[]
index_range_600 = list(range(1,len(movie_container_600)))
for index_600 in index_range_600:
    movies_600.append(movie_container_600[index_600].findAll('td'))
movies_600[0]
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">605</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0486946/?ref_=bo_cso_table_1">Wild Hogs</a></td>,
#  <td class="a-text-right mojo-field-type-money">$253,625,427</td>,
#  <td class="a-text-right mojo-field-type-money">$168,273,550</td>,
#  <td class="a-text-right mojo-field-type-percent">66.4%</td>,
#  <td class="a-text-right mojo-field-type-money">$85,351,877</td>,
#  <td class="a-text-right mojo-field-type-percent">33.6%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2007/?ref_=bo_cso_table_1">2007</a></td>]

# %%
movies_800=[]
index_range_800 = list(range(1,len(movie_container_800)))
for index_800 in index_range_800:
    movies_800.append(movie_container_800[index_800].findAll('td'))
movies_800[0]
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">808</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt0356634/?ref_=bo_cso_table_1">Garfield</a></td>,
#  <td class="a-text-right mojo-field-type-money">$203,172,417</td>,
#  <td class="a-text-right mojo-field-type-money">$75,369,589</td>,
#  <td class="a-text-right mojo-field-type-percent">37.1%</td>,
#  <td class="a-text-right mojo-field-type-money">$127,802,828</td>,
#  <td class="a-text-right mojo-field-type-percent">62.9%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2004/?ref_=bo_cso_table_1">2004</a></td>]

# %%
movies_1000=[]
index_range_1000 = list(range(1,len(movie_container_1000)))
for index_1000 in index_range_1000:
    movies_1000.append(movie_container_1000[index_1000].findAll('td'))
movies_1000[0]
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1,015</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt3682448/?ref_=bo_cso_table_1">Bridge of Spies</a></td>,
#  <td class="a-text-right mojo-field-type-money">$165,478,348</td>,
#  <td class="a-text-right mojo-field-type-money">$72,313,754</td>,
#  <td class="a-text-right mojo-field-type-percent">43.7%</td>,
#  <td class="a-text-right mojo-field-type-money">$93,164,594</td>,
#  <td class="a-text-right mojo-field-type-percent">56.3%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2015/?ref_=bo_cso_table_1">2015</a></td>]

# %%
movies_1200=[]
index_range_1200 = list(range(1,len(movie_container_1200)))
for index_1200 in index_range_1200:
    movies_1200.append(movie_container_1200[index_1200].findAll('td'))
movies_1200[0]
# Out:
# [<td class="a-text-right mojo-header-column mojo-truncate mojo-field-type-rank">1,219</td>,
#  <td class="a-text-left mojo-field-type-title"><a class="a-link-normal" href="/title/tt3541262/?ref_=bo_cso_table_1">The Admiral</a></td>,
#  <td class="a-text-right mojo-field-type-money">$138,342,258</td>,
#  <td class="a-text-right mojo-field-type-money">$2,589,811</td>,
#  <td class="a-text-right mojo-field-type-percent">1.9%</td>,
#  <td class="a-text-right mojo-field-type-money">$135,752,447</td>,
#  <td class="a-text-right mojo-field-type-percent">98.1%</td>,
#  <td class="a-text-left mojo-field-type-year"><a class="a-link-normal" href="/year/world/2014/?ref_=bo_cso_table_1">2014</a></td>]

# %%
movies[0][1].text
# Out:
# 'Avengers: Endgame'

# %%
movies_200[0][1].string
# Out:
# 'Dunkirk'

# %%
movies_400[0][1].text
# Out:
# 'Rush Hour 2'

# %%
'''Converts td values in movies to strings and
    appends to movies_string list'''
movies_string=[]
for movie in movies:
    for attribute in movie:
        movies_string.append(attribute.string)
movies_string
# Out:
# ['1',
#  'Avengers: Endgame',
#  '$2,797,800,564',
#  '$858,373,000',
#  '30.7%',
#  '$1,939,427,564',
#  '69.3%',
#  '2019',
#  '2',
#  'Avatar',
#  '$2,790,439,000',
#  '$760,507,625',
#  '27.2%',
#  '$2,029,931,375',
#  '72.8%',
#  '2009',
#  '3',
#  'Titanic',
#  '$2,194,439,542',
#  '$659,363,944',
#  '30%',
#  '$1,535,075,598',
#  '70%',
#  '1997',
#  '4',
#  'Star Wars: Episode VII - The Force Awakens',
#  '$2,068,223,624',
#  '$936,662,225',
#  '45.3%',
#  '$1,131,561,399',
#  '54.7%',
#  '2015',
#  '5',
#  'Avengers: Infinity War',
#  '$2,048,359,754',
#  '$678,815,482',
#  '33.1%',
#  '$1,369,544,272',
#  '66.9%',
#  '2018',
#  '6',
#  'Jurassic World',
#  '$1,670,400,637',
#  '$652,270,625',
#  '39%',
#  '$1,018,130,012',
#  '61%',
#  '2015',
#  '7',
#  'The Lion King',
#  '$1,656,943,394',
#  '$543,638,043',
#  '32.8%',
#  '$1,113,305,351',
#  '67.2%',
#  '2019',
#  '8',
#  'The Avengers',
#  '$1,518,812,988',
#  '$623,357,910',
#  '41%',
#  '$895,455,078',
#  '59%',
# ...

# %%
movies_string_200=[]
for movie_200 in movies_200:
    for attribute_200 in movie_200:
        movies_string_200.append(attribute_200.string)
movies_string_200
# Out:
# ['201',
#  'Dunkirk',
#  '$526,940,665',
#  '$189,740,665',
#  '36%',
#  '$337,200,000',
#  '64%',
#  '2017',
#  '202',
#  'Godzilla',
#  '$524,976,069',
#  '$200,676,069',
#  '38.2%',
#  '$324,300,000',
#  '61.8%',
#  '2014',
#  '203',
#  'Sherlock Holmes',
#  '$524,028,679',
#  '$209,028,679',
#  '39.9%',
#  '$315,000,000',
#  '60.1%',
#  '2009',
#  '204',
#  'Meet the Fockers',
#  '$522,657,936',
#  '$279,261,160',
#  '53.4%',
#  '$243,396,776',
#  '46.6%',
#  '2004',
#  '205',
#  'How to Train Your Dragon: The Hidden World',
#  '$521,799,505',
#  '$160,799,505',
#  '30.8%',
#  '$361,000,000',
#  '69.2%',
#  '2019',
#  '206',
#  'WALL·E',
#  '$521,311,860',
#  '$223,808,164',
#  '42.9%',
#  '$297,503,696',
#  '57.1%',
#  '2008',
#  '207',
#  'Kung Fu Panda 3',
#  '$521,170,825',
#  '$143,528,619',
#  '27.5%',
#  '$377,642,206',
#  '72.5%',
#  '2016',
#  '208',
#  'Terminator 2: Judgment Day',
#  '$520,884,847',
#  '$205,881,154',
#  '39.5%',
#  '$315,003,693',
#  '60.5%',
# ...

# %%
movies_string_400=[]
for movie_400 in movies_400:
    for attribute_400 in movie_400:
        movies_string_400.append(attribute_400.string)
movies_string_400
# Out:
# ['402',
#  'Rush Hour 2',
#  '$347,325,802',
#  '$226,164,286',
#  '65.1%',
#  '$121,161,516',
#  '34.9%',
#  '2001',
#  '403',
#  'Trolls',
#  '$346,864,462',
#  '$153,707,064',
#  '44.3%',
#  '$193,157,398',
#  '55.7%',
#  '2016',
#  '404',
#  'xXx: Return of Xander Cage',
#  '$346,118,277',
#  '$44,898,413',
#  '13%',
#  '$301,219,864',
#  '87%',
#  '2017',
#  '405',
#  'Pocahontas',
#  '$346,079,773',
#  '$141,579,773',
#  '40.9%',
#  '$204,500,000',
#  '59.1%',
#  '1995',
#  '406',
#  'How the Grinch Stole Christmas',
#  '$345,141,403',
#  '$260,044,825',
#  '75.3%',
#  '$85,096,578',
#  '24.7%',
#  '2000',
#  '407',
#  'Star Trek Beyond',
#  '$343,471,816',
#  '$158,848,340',
#  '46.2%',
#  '$184,623,476',
#  '53.8%',
#  '2016',
#  '408',
#  'Alvin and the Chipmunks: Chipwrecked',
#  '$342,695,435',
#  '$133,110,742',
#  '38.8%',
#  '$209,584,693',
#  '61.2%',
#  '2011',
#  '409',
#  'Wanted',
#  '$342,463,063',
#  '$134,508,551',
#  '39.3%',
#  '$207,954,512',
#  '60.7%',
# ...

# %%
movies_string_600=[]
for movie_600 in movies_600:
    for attribute_600 in movie_600:
        movies_string_600.append(attribute_600.string)
movies_string_600
# Out:
# ['605',
#  'Wild Hogs',
#  '$253,625,427',
#  '$168,273,550',
#  '66.4%',
#  '$85,351,877',
#  '33.6%',
#  '2007',
#  '606',
#  'High School Musical 3',
#  '$252,909,177',
#  '$90,559,416',
#  '35.8%',
#  '$162,349,761',
#  '64.2%',
#  '2008',
#  '607',
#  'Hercules',
#  '$252,712,101',
#  '$99,112,101',
#  '39.2%',
#  '$153,600,000',
#  '60.8%',
#  '1997',
#  '608',
#  'X-Men: Dark Phoenix',
#  '$252,442,974',
#  '$65,845,974',
#  '26.1%',
#  '$186,597,000',
#  '73.9%',
#  '2019',
#  '609',
#  'True Grit',
#  '$252,276,927',
#  '$171,243,005',
#  '67.9%',
#  '$81,033,922',
#  '32.1%',
#  '2010',
#  '610',
#  'Bean',
#  '$251,212,670',
#  '$45,319,423',
#  '18%',
#  '$205,893,247',
#  '82%',
#  '1997',
#  '611',
#  'American Hustle',
#  '$251,171,807',
#  '$150,117,807',
#  '59.8%',
#  '$101,054,000',
#  '40.2%',
#  '2013',
#  '612',
#  'Enemy of the State',
#  '$250,849,789',
#  '$111,549,836',
#  '44.5%',
#  '$139,299,953',
#  '55.5%',
#  '1998',
#  '613',
#  "You've Got Mail",
# ...

# %%
movies_string_800=[]
for movie_800 in movies_800:
    for attribute_800 in movie_800:
        movies_string_800.append(attribute_800.string)
movies_string_800
# Out:
# ['808',
#  'Garfield',
#  '$203,172,417',
#  '$75,369,589',
#  '37.1%',
#  '$127,802,828',
#  '62.9%',
#  '2004',
#  '809',
#  'Little Women',
#  '$203,127,575',
#  '$107,727,575',
#  '53%',
#  '$95,400,000',
#  '47%',
#  '2019',
#  '810',
#  'The Addams Family',
#  '$203,044,905',
#  '$100,044,905',
#  '49.3%',
#  '$103,000,000',
#  '50.7%',
#  '2019',
#  '811',
#  'Patch Adams',
#  '$202,292,902',
#  '$135,026,902',
#  '66.8%',
#  '$67,266,000',
#  '33.2%',
#  '1998',
#  '812',
#  'Teenage Mutant Ninja Turtles',
#  '$201,965,915',
#  '$135,265,915',
#  '67%',
#  '$66,700,000',
#  '33%',
#  '1990',
#  '813',
#  'Kindergarten Cop',
#  '$201,957,688',
#  '$91,457,688',
#  '45.3%',
#  '$110,500,000',
#  '54.7%',
#  '1990',
#  '814',
#  'Straight Outta Compton',
#  '$201,634,991',
#  '$161,197,785',
#  '80%',
#  '$40,437,206',
#  '20%',
#  '2015',
#  '815',
#  '21 Jump Street',
#  '$201,585,328',
#  '$138,447,667',
#  '68.7%',
#  '$63,137,661',
#  '31.3%',
#  '2012',
#  '816',
# ...

# %%
movies_string_1000=[]
for movie_1000 in movies_1000:
    for attribute_1000 in movie_1000:
        movies_string_1000.append(attribute_1000.string)
movies_string_1000
# Out:
# ['1,015',
#  'Bridge of Spies',
#  '$165,478,348',
#  '$72,313,754',
#  '43.7%',
#  '$93,164,594',
#  '56.3%',
#  '2015',
#  '1,016',
#  'The Princess Diaries',
#  '$165,335,153',
#  '$108,248,956',
#  '65.5%',
#  '$57,086,197',
#  '34.5%',
#  '2001',
#  '1,017',
#  'The Muppets',
#  '$165,184,237',
#  '$88,631,237',
#  '53.7%',
#  '$76,553,000',
#  '46.3%',
#  '2011',
#  '1,018',
#  "The Huntsman: Winter's War",
#  '$164,989,338',
#  '$48,390,190',
#  '29.3%',
#  '$116,599,148',
#  '70.7%',
#  '2016',
#  '1,019',
#  'Saw III',
#  '$164,874,275',
#  '$80,238,724',
#  '48.7%',
#  '$84,635,551',
#  '51.3%',
#  '2006',
#  '1,020',
#  'Six Days Seven Nights',
#  '$164,839,294',
#  '$74,339,294',
#  '45.1%',
#  '$90,500,000',
#  '54.9%',
#  '1998',
#  '1,021',
#  'Bringing Down the House',
#  '$164,729,679',
#  '$132,716,677',
#  '80.6%',
#  '$32,013,002',
#  '19.4%',
#  '2003',
#  '1,022',
#  'Deep Blue Sea',
#  '$164,648,142',
#  '$73,648,142',
#  '44.7%',
#  '$91,000,000',
#  '55.3%',
# ...

# %%
movies_string_1200=[]
for movie_1200 in movies_1200:
    for attribute_1200 in movie_1200:
        movies_string_1200.append(attribute_1200.string)
movies_string_1200
# Out:
# ['1,219',
#  'The Admiral',
#  '$138,342,258',
#  '$2,589,811',
#  '1.9%',
#  '$135,752,447',
#  '98.1%',
#  '2014',
#  '1,220',
#  "America's Sweethearts",
#  '$138,307,673',
#  '$93,607,673',
#  '67.7%',
#  '$44,700,000',
#  '32.3%',
#  '2001',
#  '1,221',
#  "Let's Be Cops",
#  '$138,224,951',
#  '$82,390,774',
#  '59.6%',
#  '$55,834,177',
#  '40.4%',
#  '2014',
#  '1,222',
#  'Far and Away',
#  '$137,783,840',
#  '$58,883,840',
#  '42.7%',
#  '$78,900,000',
#  '57.3%',
#  '1992',
#  '1,223',
#  'Bridge to Terabithia',
#  '$137,587,063',
#  '$82,272,442',
#  '59.8%',
#  '$55,314,621',
#  '40.2%',
#  '2007',
#  '1,224',
#  'Stardust',
#  '$137,515,140',
#  '$38,634,938',
#  '28.1%',
#  '$98,880,202',
#  '71.9%',
#  '2007',
#  '1,225',
#  'Escape Plan',
#  '$137,328,301',
#  '$25,135,965',
#  '18.3%',
#  '$112,192,336',
#  '81.7%',
#  '2013',
#  '1,226',
#  'Last Action Hero',
#  '$137,298,489',
#  '$50,016,394',
#  '36.4%',
#  '$87,282,095',
#  '63.6%',
#  '1993',
#  '1,227',
# ...

# %%
# Checking length of movies_string 
len(movies_string)
# Out:
# 1600

# %%
len(movies_string_200)
# Out:
# 1600

# %%
# Combine all lists into one list
movies_list_test=list(movies_string+movies_string_200+movies_string_400+movies_string_600+movies_string_800+movies_string_1000+movies_string_1200)
movies_list_test
len(movies_list_test)
# Out:
# 11200

# %%
import pandas as pd
import numpy as np

# %%
# Convert combined list into array
movies_list=np.array(movies_list_test)
movies_list
# Out:
# array(['1', 'Avengers: Endgame', '$2,797,800,564', ..., '$44,218,118',
#        '37.7%', '2009'], dtype='<U83')

# %%
# Rearrange array into list of 1400 films by 8 attributes
reshaped=movies_list.reshape(1400,8)
# Make dataframe with column titles from headers_string 
df=pd.DataFrame(reshaped, columns=headers_string)

# %%
df
# Out:
#        Rank                                       Title  \
# 0         1                           Avengers: Endgame
# 1         2                                      Avatar
# 2         3                                     Titanic
# 3         4  Star Wars: Episode VII - The Force Awakens
# 4         5                      Avengers: Infinity War
# ...     ...                                         ...
# 1395  1,420                                  The Client
# 1396  1,421                               The Forgotten
# 1397  1,422                             A Knight's Tale
# 1398  1,423                           Dennis the Menace
# 1399  1,424                              Hotel for Dogs
#
#      Worldwide Lifetime Gross Domestic Lifetime Gross Domestic %  \
# 0              $2,797,800,564            $858,373,000      30.7%
# 1              $2,790,439,000            $760,507,625      27.2%
# 2              $2,194,439,542            $659,363,944        30%
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 8 columns):
# Rank                        1400 non-null object
# Title                       1400 non-null object
# Worldwide Lifetime Gross    1400 non-null object
# Domestic Lifetime Gross     1400 non-null object
# Domestic %                  1400 non-null object
# Foreign Lifetime Gross      1400 non-null object
# Foreign %                   1400 non-null object
# Year                        1400 non-null object
# dtypes: object(8)
# memory usage: 87.6+ KB

# %%
type(df.Year)
# Out:
# pandas.core.series.Series

# %%
# Change year from string to integer
from decimal import Decimal
from re import sub

# %%
df['Year']=pd.to_numeric(df['Year'])

# %%
df['Year']
# Out:
# 0       2019
# 1       2009
# 2       1997
# 3       2015
# 4       2018
#         ...
# 1395    1994
# 1396    2004
# 1397    2001
# 1398    1993
# 1399    2009
# Name: Year, Length: 1400, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 8 columns):
# Rank                        1400 non-null object
# Title                       1400 non-null object
# Worldwide Lifetime Gross    1400 non-null object
# Domestic Lifetime Gross     1400 non-null object
# Domestic %                  1400 non-null object
# Foreign Lifetime Gross      1400 non-null object
# Foreign %                   1400 non-null object
# Year                        1400 non-null int64
# dtypes: int64(1), object(7)
# memory usage: 87.6+ KB

# %%
df['Worldwide Lifetime Gross'][0]
# Out:
# '$2,797,800,564'

# %%
# Convert monetary values from string to float, imported locale
import locale
import pandas as pd
locale.setlocale(locale.LC_ALL,'')

# use locale.atof to strip $ and convert to float using lambda function
df['Worldwide Lifetime Gross']=df['Worldwide Lifetime Gross'].map(lambda x: locale.atof(x.strip('$')))

# %%
df['Domestic Lifetime Gross']=df['Domestic Lifetime Gross'].map(lambda x: locale.atof(x.strip('$')))

# %%
df['Foreign Lifetime Gross']=df['Foreign Lifetime Gross'].map(lambda x: locale.atof(x.strip('$')))

# %%
df['Worldwide Lifetime Gross']
# Out:
# 0       2.797801e+09
# 1       2.790439e+09
# 2       2.194440e+09
# 3       2.068224e+09
# 4       2.048360e+09
#             ...
# 1395    1.176152e+08
# 1396    1.175928e+08
# 1397    1.174875e+08
# 1398    1.172708e+08
# 1399    1.172526e+08
# Name: Worldwide Lifetime Gross, Length: 1400, dtype: float64

# %%
df['Domestic Lifetime Gross']
# Out:
# 0       858373000.0
# 1       760507625.0
# 2       659363944.0
# 3       936662225.0
# 4       678815482.0
#            ...
# 1395     92115211.0
# 1396     67133509.0
# 1397     56569702.0
# 1398     51270765.0
# 1399     73034460.0
# Name: Domestic Lifetime Gross, Length: 1400, dtype: float64

# %%
df['Foreign Lifetime Gross']
# Out:
# 0       1.939428e+09
# 1       2.029931e+09
# 2       1.535076e+09
# 3       1.131561e+09
# 4       1.369544e+09
#             ...
# 1395    2.550000e+07
# 1396    5.045932e+07
# 1397    6.091777e+07
# 1398    6.600000e+07
# 1399    4.421812e+07
# Name: Foreign Lifetime Gross, Length: 1400, dtype: float64

# %%
# Turn Rank from string into integer, replace remove commas
df['Rank']=df['Rank'].map(lambda x: int(x.replace(',','')))

# %%
df['Rank']
# Out:
# 0          1
# 1          2
# 2          3
# 3          4
# 4          5
#         ...
# 1395    1420
# 1396    1421
# 1397    1422
# 1398    1423
# 1399    1424
# Name: Rank, Length: 1400, dtype: int64

# %%
# Replace '-' values with 0%
df['Domestic %']=df['Domestic %'].map(lambda x: x.replace('-','0%'))
df['Domestic %']
# Out:
# 0       30.7%
# 1       27.2%
# 2         30%
# 3       45.3%
# 4       33.1%
#         ...
# 1395    78.3%
# 1396    57.1%
# 1397    48.2%
# 1398    43.7%
# 1399    62.3%
# Name: Domestic %, Length: 1400, dtype: object

# %%
# Some values had '<' sign; removed with lambda function
df['Domestic %']=df['Domestic %'].map(lambda x: x.replace('<',''))
df['Domestic %']
# Out:
# 0       30.7%
# 1       27.2%
# 2         30%
# 3       45.3%
# 4       33.1%
#         ...
# 1395    78.3%
# 1396    57.1%
# 1397    48.2%
# 1398    43.7%
# 1399    62.3%
# Name: Domestic %, Length: 1400, dtype: object

# %%
# Converted % string to float
df['Domestic %']=df['Domestic %'].map(lambda x: float(x.replace('%','')))
df['Domestic %']
# Out:
# 0       30.7
# 1       27.2
# 2       30.0
# 3       45.3
# 4       33.1
#         ...
# 1395    78.3
# 1396    57.1
# 1397    48.2
# 1398    43.7
# 1399    62.3
# Name: Domestic %, Length: 1400, dtype: float64

# %%
df['Foreign %']=df['Domestic %'].map(lambda x: 100-x)
df['Foreign %']
# Out:
# 0       69.3
# 1       72.8
# 2       70.0
# 3       54.7
# 4       66.9
#         ...
# 1395    21.7
# 1396    42.9
# 1397    51.8
# 1398    56.3
# 1399    37.7
# Name: Foreign %, Length: 1400, dtype: float64

# %%
# Cleaned dataframe result
df
# Out:
#       Rank                                       Title  \
# 0        1                           Avengers: Endgame
# 1        2                                      Avatar
# 2        3                                     Titanic
# 3        4  Star Wars: Episode VII - The Force Awakens
# 4        5                      Avengers: Infinity War
# ...    ...                                         ...
# 1395  1420                                  The Client
# 1396  1421                               The Forgotten
# 1397  1422                             A Knight's Tale
# 1398  1423                           Dennis the Menace
# 1399  1424                              Hotel for Dogs
#
#       Worldwide Lifetime Gross  Domestic Lifetime Gross  Domestic %  \
# 0                 2.797801e+09              858373000.0        30.7
# 1                 2.790439e+09              760507625.0        27.2
# 2                 2.194440e+09              659363944.0        30.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1400 entries, 0 to 1399
# Data columns (total 8 columns):
# Rank                        1400 non-null int64
# Title                       1400 non-null object
# Worldwide Lifetime Gross    1400 non-null float64
# Domestic Lifetime Gross     1400 non-null float64
# Domestic %                  1400 non-null float64
# Foreign Lifetime Gross      1400 non-null float64
# Foreign %                   1400 non-null float64
# Year                        1400 non-null int64
# dtypes: float64(5), int64(2), object(1)
# memory usage: 87.6+ KB

# %%
#Finding remakes or reboots with same title
df_dup=df[df['Title'].duplicated(keep=False)]
df_dup.sort_values('Title',ascending=True)
# Out:
#       Rank                         Title  Worldwide Lifetime Gross  \
# 36      37                       Aladdin              1.050694e+09
# 211    212                       Aladdin              5.040502e+08
# 16      17          Beauty and the Beast              1.263521e+09
# 267    268          Beauty and the Beast              4.401184e+08
# 1288  1309                       Everest              1.279901e+08
# 795    803                       Everest              2.034276e+08
# 992   1007                Fantastic Four              1.678829e+08
# 421    424                Fantastic Four              3.335359e+08
# 681    687                  Ghostbusters              2.291475e+08
# 506    510                  Ghostbusters              2.957438e+08
# 328    329                      Godzilla              3.790143e+08
# 201    202                      Godzilla              5.249761e+08
# 602    607                      Hercules              2.527121e+08
# ...

# %%
df['Title'][36]='Aladdin (2009)'
df['Title'][36]
# Out:
# C:\Users\mmsub\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# 'Aladdin (2009)'

# %%
df[df['Title'].duplicated(keep=False)].sort_values('Title',ascending=True)
# Out:
#       Rank                         Title  Worldwide Lifetime Gross  \
# 16      17          Beauty and the Beast              1.263521e+09
# 267    268          Beauty and the Beast              4.401184e+08
# 1288  1309                       Everest              1.279901e+08
# 795    803                       Everest              2.034276e+08
# 992   1007                Fantastic Four              1.678829e+08
# 421    424                Fantastic Four              3.335359e+08
# 681    687                  Ghostbusters              2.291475e+08
# 506    510                  Ghostbusters              2.957438e+08
# 328    329                      Godzilla              3.790143e+08
# 201    202                      Godzilla              5.249761e+08
# 602    607                      Hercules              2.527121e+08
# 631    637                      Hercules              2.448199e+08
# 223    224  Teenage Mutant Ninja Turtles              4.850048e+08
# ...

# %%
'''Found indices of values that needed to be changed,
would have used a function or loop but there were time constraints'''
print(df['Title'][16])
print(df['Title'][795])
print(df['Title'][992])
print(df['Title'][681])
print(df['Title'][201])
print(df['Title'][631])
print(df['Title'][223])
print(df['Title'][802])
print(df['Title'][819])
print(df['Title'][50])
print(df['Title'][6])
print(df['Title'][295])
print(df['Title'][818])
# Out:
# Beauty and the Beast
# Everest
# Fantastic Four
# Ghostbusters
# Godzilla
# Hercules
# Teenage Mutant Ninja Turtles
# The Addams Family
# The Island
# The Jungle Book
# The Lion King
# The Mummy
# Total Recall

# %%
# added (Year) to string of most recent remake or reboot
df['Title'][16]='Beauty and the Beast (2017)'
df['Title'][795]='Everest (2015)'
df['Title'][992]='Fantastic Four (2015)'
df['Title'][681]='Ghostbusters (2016)'
df['Title'][201]='Godzilla (2014)'
df['Title'][631]='Hercules (2014)'
df['Title'][223]='Teenage Mutant Ninja Turtles (2014)'
df['Title'][802]='The Addams Family (2019)'
df['Title'][819]='The Island (2018)'
df['Title'][50]='The Jungle Book (2016)'
df['Title'][6]='The Lion King (2019)'
df['Title'][295]='The Mummy (2017)'
df['Title'][818]='Total Recall (2012)'
# Out:
# C:\Users\mmsub\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# C:\Users\mmsub\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\mmsub\Anaconda3\envs\learn-env\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df
# Out:
#       Rank                                       Title  \
# 0        1                           Avengers: Endgame
# 1        2                                      Avatar
# 2        3                                     Titanic
# 3        4  Star Wars: Episode VII - The Force Awakens
# 4        5                      Avengers: Infinity War
# ...    ...                                         ...
# 1395  1420                                  The Client
# 1396  1421                               The Forgotten
# 1397  1422                             A Knight's Tale
# 1398  1423                           Dennis the Menace
# 1399  1424                              Hotel for Dogs
#
#       Worldwide Lifetime Gross  Domestic Lifetime Gross  Domestic %  \
# 0                 2.797801e+09              858373000.0        30.7
# 1                 2.790439e+09              760507625.0        27.2
# 2                 2.194440e+09              659363944.0        30.0
# ...

# %%
# Checking if remakes/reboots don't show up
df[df['Title'].duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Rank, Title, Worldwide Lifetime Gross, Domestic Lifetime Gross, Domestic %, Foreign Lifetime Gross, Foreign %, Year]
# Index: []

# %%
# creating .csv file for GitHub
df.to_csv('box_office_mojo_cleaned.csv')
